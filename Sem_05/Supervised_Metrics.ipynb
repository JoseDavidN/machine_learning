# %% [markdown]
# # Clasification

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import make_classification

# import classifiers
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as kNN

# Import validation
from sklearn.model_selection import train_test_split

# %%
# we create 100 separable points
X, y = make_classification(n_samples = 1000, n_features=2, n_classes = 3, n_redundant=0, n_informative=2, n_clusters_per_class=1, random_state=6)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

print(X.shape, y.shape)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

# Plot train / test data
_, axes = plt.subplots(1, 2, figsize=(8, 4))
axes[0].scatter(X[:, 0], X[:, 1], c = y, edgecolors="k", cmap="Paired")
axes[1].scatter(X_train[:, 0], X_train[:, 1], c='r', edgecolors="k")
axes[1].scatter(X_test[:, 0], X_test[:, 1], c='b', edgecolors='b')
# Out:
# (1000, 2) (1000,)
# (800, 2) (800,) (200, 2) (200,)

# %%
'''
    --> Paste your plot_2d_decision_boundaries function here!
'''

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Semestre_9/machine_learning
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Semestre_9/machine_learning

# %%
from Tools.desicion_boundaries import desicionBoundaries

# %%
models = [ LogisticRegression() , kNN(n_neighbors=7) , SVC(kernel='poly'), SVC(kernel='rbf') ]

names = ['Logistic Regresion', 'kNN (neighbors)', 'SVM (Poly)', 'SVM (RBF)']

_, axes = plt.subplots(1, len(models), figsize = (5*len(models),5))
predictions = {}

# fit the models
for clf, name, ax in zip(models, names, axes) :
    #
    clf.fit( X_train , y_train )
    predictions[name] = clf.predict(X_test)

    # Plot everything
    desicionBoundaries(clf, X_test, y_test, ax=ax)

plt.show()
# Out:
# h_grid (730, 585) v_grid (730, 585) (427050,) (427050,)
# (427050, 2)
# (427050,)
# (730, 585)
# h_grid (730, 585) v_grid (730, 585) (427050,) (427050,)
# (427050, 2)
# (427050,)
# (730, 585)
# h_grid (730, 585) v_grid (730, 585) (427050,) (427050,)
# (427050, 2)
# (427050,)
# (730, 585)
# h_grid (730, 585) v_grid (730, 585) (427050,) (427050,)
# (427050, 2)
# (427050,)
# (730, 585)

# %% [markdown]
# ## Metricas de desempeño
#
# Módulo de [Metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) de sklearn

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns

# %%
_, axes = plt.subplots(1, len(models) , figsize = (4*len(models),4))

# Compute metrics - plot confusion matrix
for name, ax in zip(names, axes) :
  print ("########----- Results for {0} -----########".format( name ))
  accuracy = accuracy_score( y_test , predictions[name] )
  precision = precision_score( y_test , predictions[name] , average = "micro")
  recall = recall_score( y_test , predictions[name] , average = "micro")
  f1 = f1_score( y_test , predictions[name] , average = "micro")
  cm = confusion_matrix( y_test , predictions[name] )
  ##--------------
  print("-- Acc --\t -- Prec --\t -- Rec --\t -- F1 --  ")
  print("  {0:.3f}  \t   {1:.3f}  \t   {2:.3f}  \t   {3:.3f}  \t".format(accuracy, precision, recall, f1))
  sns.heatmap(cm, cmap = "hot", annot = True, ax = ax )
  ax.set_title( name )
# Out:
# ########----- Results for Logistic Regresion -----########
# -- Acc --	 -- Prec --	 -- Rec --	 -- F1 --
#   0.945  	   0.945  	   0.945  	   0.945
# ########----- Results for kNN (neighbors) -----########
# -- Acc --	 -- Prec --	 -- Rec --	 -- F1 --
#   0.935  	   0.935  	   0.935  	   0.935
# ########----- Results for SVM (Poly) -----########
# -- Acc --	 -- Prec --	 -- Rec --	 -- F1 --
#   0.930  	   0.930  	   0.930  	   0.930
# ########----- Results for SVM (RBF) -----########
# -- Acc --	 -- Prec --	 -- Rec --	 -- F1 --
#   0.945  	   0.945  	   0.945  	   0.945

# %% [markdown]
# ## En datos reales

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import load_digits

# import classifiers
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as kNN

# %%
digits = load_digits()
print(digits.data.shape)

plt.imshow(digits.images[0].reshape(8,8), cmap="gray")
# Out:
# (1797, 64)

# %% [markdown]
# Evalúe los distintos algoritmos entrenando con esta base de datos.

# %% [markdown]
# # Regression

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt

# import data
from sklearn.datasets import make_regression

# import classifiers
from sklearn.linear_model import LinearRegression

# Import validation
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples = 1000, n_features = 1 , noise = 10 , random_state = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)


np.random.seed(0)
y_test = y_test + np.random.normal(len(y_test)) * 0.1

# Plot train / test data
_, axes = plt.subplots(1, 2, figsize=(8,4))
axes[0].scatter(X, y, c='b')
axes[1].scatter(X_train, y_train, s=30, edgecolor='k', c='r')
axes[1].scatter(X_test, y_test, s=30, edgecolor='k', c='g')

# %%
# Train a linear regression
linear_regresion = LinearRegression()
linear_regresion.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Metricas de desempeño
#
# Módulo de [Metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) de sklearn

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Compute MAE and MSE
predictions = linear_regresion.predict(X_test)
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print("MSE {0:.5f}".format(mse))
print("MAE {0:.5f}".format(mae))
# Out:
# MSE 513.32414
# MAE 20.32431
